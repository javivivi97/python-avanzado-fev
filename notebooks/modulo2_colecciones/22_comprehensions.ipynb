# %% [markdown]
# # 🧩 2.2 – Comprensiones de Listas, Diccionarios y Conjuntos
#
# Las **comprensiones** son una forma compacta y expresiva de construir colecciones a partir de otras. Permiten aplicar **filtros, transformaciones y condiciones** en una sola línea.
#
# ---
# ## 🎯 Objetivos
# - Comprender la sintaxis de las comprensiones.
# - Crear listas, diccionarios y conjuntos por comprensión.
# - Aplicar condiciones y expresiones anidadas.
# - Comparar rendimiento frente a bucles tradicionales.

# %%
print('✅ Comprensiones listas para practicar.')
# Out:
# ✅ Comprensiones listas para practicar.

# %% [markdown]
# ---
# ## 1️⃣ Comprensiones de listas (`list comprehension`)
#
# Sintaxis general:
# ```python
# [expresion for elemento in iterable if condicion]
# ```
#
# Equivale a un bucle `for` con un `append`, pero más conciso y rápido.

# %%
# Ejemplo básico
numeros = [1, 2, 3, 4, 5]
cuadrados = [n**2 for n in numeros]
print(cuadrados)

# Con condición
pares = [n for n in numeros if n % 2 == 0]
print(pares)
# Out:
# [1, 4, 9, 16, 25]
# [2, 4]

# %%
cuadrados = []
for x in [1,4,6]:
         cuadrados.append(x**2)

cuadrados = [x**2 for x in [1,4,6]]

print(cuadrados)
# Out:
# [1, 16, 36]

# %% [markdown]
# ✅ Más legible, más rápido, y evita escribir bucles innecesarios.
#
# 👉 Se pueden anidar varias condiciones y operaciones.

# %% [markdown]
# ---
# ## 2️⃣ Comprensiones de diccionarios (`dict comprehension`)
#
# Sintaxis general:
# ```python
# {clave: valor for elemento in iterable if condicion}
# ```
#
# Permite crear diccionarios dinámicamente a partir de listas o tuplas.

# %%
# Crear un diccionario de números y sus cuadrados
cuadrados_dict = {n: n**2 for n in range(1, 6)}
print(cuadrados_dict)

# Filtrar solo los pares
pares_dict = {n: n**2 for n in range(1, 6) if n % 2 == 0}
print(pares_dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# {2: 4, 4: 16}

# %%
cuadrado_dict ={}

for n in range(1, 6):
    if len(n) > 4:
        cuadrados_dict[n] = n**2

print(cuadrados_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 cuadrado_dict ={}
#       3 for n in range(1, 6):
# ----> 4     if len(n) > 4:
#       5         cuadrados_dict[n] = n**2
#       7 print(cuadrados_dict)
#
# TypeError: object of type 'int' has no len()

# %% [markdown]
# ✅ Muy útil para construir mapas o transformar claves/valores de otro diccionario.

# %% [markdown]
# ---
# ## 3️⃣ Comprensiones de conjuntos (`set comprehension`)
#
# Sintaxis:
# ```python
# {expresion for elemento in iterable if condicion}
# ```
#
# Igual que las de lista, pero el resultado es un **set sin duplicados**.

# %%
frutas = ['manzana', 'pera', 'manzana', 'kiwi', 'pera']
unicas = {f for f in frutas}
print(unicas)

# Mayúsculas solo para frutas con más de 4 letras
transformadas = {f.upper() for f in frutas if len(f) > 4}
print(transformadas)
# Out:
# {'pera', 'kiwi', 'manzana'}
# {'MANZANA'}

# %% [markdown]
# ✅ Las comprensiones de conjuntos son perfectas para eliminar duplicados y aplicar transformaciones al mismo tiempo.

# %% [markdown]
# ---
# ## 4️⃣ Comprensiones anidadas
#
# Permiten generar estructuras bidimensionales o combinar múltiples iterables.

# %%
matriz = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
flatten = [x for fila in matriz for x in fila]
print(flatten)

pares = [(x, y) for x in [1, 2, 3] for y in ['a', 'b']]
print(pares)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b'), (3, 'a'), (3, 'b')]

# %% [markdown]
# 👉 El orden de los `for` importa: se ejecutan de izquierda a derecha tal como en bucles anidados.

# %% [markdown]
# ---
# ## 5️⃣ Comprensiones con funciones
#
# Podemos llamar funciones dentro de la expresión de comprensión.

# %%
def cuadrado(x):
    return x * x

resultado = [cuadrado(n) for n in range(1, 6)]
print(resultado)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ✅ Esto hace que las comprensiones sean útiles para **aplicar transformaciones a gran escala** en datos o listas de objetos.

# %% [markdown]
# ---
# ## 6️⃣ Ejercicio práctico
#
# Dada la lista:
# ```python
# personas = [
#     {'nombre': 'Ana', 'edad': 30},
#     {'nombre': 'Luis', 'edad': 22},
#     {'nombre': 'María', 'edad': 17},
#     {'nombre': 'Pepe', 'edad': 40}
# ]
# ```
# 1. Crea una lista con los nombres en mayúsculas de las personas mayores de edad.
# 2. Crea un diccionario `{nombre: edad}` solo para mayores de 25.
# 3. Genera un conjunto con las edades únicas.

# %%
personas = [
    {'nombre': 'Ana', 'edad': 30},
    {'nombre': 'Luis', 'edad': 22},
    {'nombre': 'María', 'edad': 17},
    {'nombre': 'Pepe', 'edad': 40}
]

# %%
# 1. Crea una lista con los nombres en mayúsculas de las personas mayores de edad.
# Versión larga sin comprehension list.

mayor_edad = []

for i in range(len(personas)):
    if personas[i]['edad'] > 18:
        mayor_edad.append(personas[i]['nombre'].upper())

print(mayor_edad)
# Out:
# ['ANA', 'LUIS', 'PEPE']

# %%
# 1. Crea una lista con los nombres en mayúsculas de las personas mayores de edad.
# Versión con comprehension list.

mayor_edad_comp = [personas[i]['nombre'].upper() for i in range(len(personas)) if personas[i]['edad'] > 18]
mayor_edad_comp
# Out:
# ['ANA', 'LUIS', 'PEPE']

# %%
# Iterar sobre lista de diccionarios:

lista_iter = [persona['nombre'].upper() for persona in personas if persona['edad'] > 18]
lista_iter
# Out:
# ['ANA', 'LUIS', 'PEPE', 'LORENA']

# %%
# 2. Crea un diccionario {nombre: edad} solo para mayores de 25.

mayores_25 = {persona['nombre']: persona['edad'] for persona in personas if persona['edad'] > 25}
mayores_25
# Out:
# {'Ana': 30, 'Pepe': 40, 'Lorena': 30}

# %%
# 3. Genera un conjunto con las edades únicas

set_edades = {persona['edad'] for persona in personas}
set_edades
# Out:
# {17, 22, 30, 40}

# %% [markdown]
# **SOLUCIÓN**

# %%
personas = [
    {'nombre': 'Ana', 'edad': 30},
    {'nombre': 'Luis', 'edad': 22},
    {'nombre': 'María', 'edad': 17},
    {'nombre': 'Pepe', 'edad': 40},
    {'nombre': 'Lorena', 'edad': 30}
]

mayores = [p['nombre'].upper() for p in personas if p['edad'] >= 18]
mayores_25 = {p['nombre']: p['edad'] for p in personas if p['edad'] > 25}
edades = {p['edad'] for p in personas}

print(mayores)
print(mayores_25)
print(edades)
# Out:
# ['ANA', 'LUIS', 'PEPE', 'LORENA']
# {'Ana': 30, 'Pepe': 40, 'Lorena': 30}
# {40, 17, 30, 22}

# %% [markdown]
# ---
# ## 🧠 Resumen del notebook
#
# - Las **comprensiones** son una herramienta elegante para crear colecciones en una sola línea.
# - Se pueden aplicar filtros, condiciones y funciones.
# - Existen versiones para `list`, `dict` y `set`.
# - Mejoran la legibilidad y rendimiento frente a bucles tradicionales.
#
# 💡 Dominar las comprensiones te hará escribir código más claro, compacto y eficiente.
