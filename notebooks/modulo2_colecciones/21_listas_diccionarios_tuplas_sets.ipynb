# %% [markdown]
# # 🧩 2.1 – Listas, Tuplas, Diccionarios y Sets
#
# En este notebook exploraremos las **principales colecciones nativas** de Python:
#
# - `list`: listas ordenadas y mutables.
# - `tuple`: tuplas ordenadas e inmutables.
# - `dict`: diccionarios clave–valor.
# - `set`: conjuntos sin duplicados.
#
# Cada una tiene propiedades, métodos y usos específicos en el procesamiento de datos.
#
# ---
# ## 🎯 Objetivos
# - Comprender la estructura, mutabilidad y uso de cada tipo.
# - Aprender operaciones comunes (agregar, eliminar, recorrer, filtrar).
# - Comparar rendimiento y casos de uso.
# - Usar comprensiones para construir colecciones rápidamente.

# %%
print('✅ Colecciones en Python listas para explorar.')
# Out:
# ✅ Colecciones en Python listas para explorar.

# %% [markdown]
# ---
# ## 1️⃣ Listas (`list`)
#
# Las listas son **colecciones ordenadas y mutables**. Permiten almacenar cualquier tipo de elemento, incluso mezclado.

# %%
frutas = ['manzana', 'pera', 'naranja']
print(frutas)

# Acceso y modificación
frutas[1] = 'plátano'
frutas.append('kiwi')
print(frutas)
# Out:
# ['manzana', 'pera', 'naranja']
# ['manzana', 'plátano', 'naranja', 'kiwi']

# %% [markdown]
# ✅ Métodos comunes: `append`, `insert`, `remove`, `pop`, `sort`, `reverse`.
#
# 👉 Las listas son ideales para colecciones **ordenadas y modificables**.

# %% [markdown]
# **Métodos principales:**
#
# - .append(): añade un elemento al final de la lista -> lista.append(valor)
# - .insert(): inserta un elemento en una posición concreta -> lista.insert(indice, valor)
# - .remove(): elimina la primera ocurrencia de un valor -> lista.remove(valor)
# - .pop(): elimina y devuelve un elemento -> lista.pop() -> elimina el último
# - .pop(índice): elimina y devuelve un índice concreto -> lista.pop(índice) -> elimina y devuelve el índice concreto.
#                 hay que acumularla en una variable. y = lista.pop(índice) -> acumula el valor eliminado en la variable y
# - .sort(): ordena la lista in place (modifica la lista original) -> lista.sort(reverse= True)
# - .reverse(): invierte el orden de la lista in place (no crea una lista nueva) -> lista.reverse()

# %% [markdown]
# ---
# ## 2️⃣ Tuplas (`tuple`)
#
# Las tuplas son **inmutables**: una vez creadas, no se pueden modificar. Son más **ligeras y seguras para datos fijos**.

# %%
coordenadas = (10, 20)
print(coordenadas)

# coordenadas[0] = 99  # ❌ Error: las tuplas no se pueden modificar
print(len(coordenadas))
# Out:
# (10, 20)
# 2

# %% [markdown]
# ✅ Las tuplas se usan frecuentemente para **devolver múltiples valores** de una función o como claves de diccionario.

# %% [markdown]
# ---
# ## 3️⃣ Diccionarios (`dict`)
#
# Colecciones **clave → valor**. Muy utilizados para representar **datos estructurados** (como registros o JSON).

# %%
persona = {
    'nombre': 'Ana',
    'edad': 30,
    'ciudad': 'Valencia'
}
print(persona)

# Acceso y actualización
persona['edad'] = 31
persona['profesion'] = 'ingeniera'
print(persona)
# Out:
# {'nombre': 'Ana', 'edad': 30, 'ciudad': 'Valencia'}
# {'nombre': 'Ana', 'edad': 31, 'ciudad': 'Valencia', 'profesion': 'ingeniera'}

# %% [markdown]
# **NOTA:** si la clave existe, se actualiza (edad). Si la clave no existe (profesión), se crea con el valor que le demos (ingeniera).

# %% [markdown]
# ✅ Métodos comunes: `keys()`, `values()`, `items()`, `get()`, `update()`.
#
# 👉 Son mutables y rápidos para búsquedas por clave.

# %% [markdown]
# - .keys(): devuelve una lista con todas las claves -> dict.keys()
# - .values(): devuelve una lista con todos los valores -> dict.values()
# - .items(): devuelve pares (clave, valor) -> dict.items()
# - .get(): devuelve el valor de una clave. Si la clave no existe, devuelve None o un valor por defecto ->
#             dict.get(clave, valor_por_defecto)
# - .pop(): elimina una clave y devuelve su valor -> dict.pop('a') -> se queda con su valor
# - .popitem(): elimina y devuelve ul último par (clave, valor) insertado -> dict.popitem()
# - .update(): actualiza el diccionario con pares de otro diccionario u objeto iterable -> dict.update({'c': 3})
# - .setdefault(): devuelve el valor de una clave. Si la clave no existe, la crea con un valor por defecto. Es como
#                 get, pero crea la clave si no existe -> dict.setdefault("x", 0)
# - .clear(): vacía el diccionario -> dict.clear()

# %% [markdown]
# ---
# ## 4️⃣ Conjuntos (`set`)
#
# Colecciones **no ordenadas y sin duplicados**. Útiles para eliminar repetidos o realizar operaciones matemáticas de conjuntos.

# %%
colores = {'rojo', 'verde', 'azul', 'rojo'}
print(colores)  # Elimina duplicados automáticamente

otros = {'azul', 'negro'}
print('Unión:', colores | otros)
print('Intersección:', colores & otros)
print('Diferencia:', colores - otros)
# Out:
# {'azul', 'rojo', 'verde'}
# Unión: {'negro', 'azul', 'verde', 'rojo'}
# Intersección: {'azul'}
# Diferencia: {'rojo', 'verde'}

# %% [markdown]
# ✅ Muy útiles para comparar colecciones o eliminar duplicados de una lista con `set(lista)`.

# %% [markdown]
# **MÉTODOS PRINCIPALES:**
#
# *Métodos*
# - .add(): añade un elemento. Si ya existe, no pasa nada -> set.add(valor_a_añadir)
# - .remove(): elimina un elemento. Si no existe, lanza error -> set.remove(valor_a_eliminar)
# - .discard(): elimina un elemento. Si no existe, no lanza errror, no hace nada -> s.discard(valor_a_eliminar)
# - .pop(): elimina un elemento arbitrario y lo devuelve -> valor = set.pop()
# - .clear(): vacía el set -> set.clear()
# - .update(): añade varios elementos desde otro iterable -> s.update([3, 4, 5])
#
# *Operaciones matemáticas básicas*
# - .union(): devuelve un nuevo set con elementos de ambos -> a.union(b)
# - .intersection(): elementos comunes -> a.intersection(b)
# - .difference(): elementos que están en "a" pero no en "b" -> a.difference(b)
# - .symmetric_difference(): elementos que están en uno u otro, pero no en ambos -> a.symmetric_difference(b)
#
# *Métodos de actualización (modifican el set)*
# - .intersection_update(): conserva solo los elementos comunes -> a.intersection_update(b)
# - .difference_update(): elimina del set actual los elementos del otro -> a.difference_update(b)
# - .symmetric_difference_update(): deja solo los elementos que están en uno u otro, pero no ambos ->
#                                     a.symmetric_difference_update(b)
# *Métodos de comparación*
# - .issubset(): ¿todos los elementos de A están en B? -> a.issubset(b)
# - .issuperset(): ¿A contiene todos los elementos de B? -> a.issuperset(b)
# - .isdisjoint(): ¿no tienen ningún elemento en común? -> a.isdisjoint(b)

# %% [markdown]
# ---
# ## 4️⃣.1️⃣ Diccionario especial - defaultdict()
#
# Es un diccionario especial que crea automáticamente un valor por defecto para cualquier clave nueva sin necesidad de inicializarla. Por el resto, se comporta igual que un diccionario normal.
#
# **Se importa desde: from collections import defaultdict**

# %%
# Ejemplo: queremos contar las veces que sale un número en una lista.

from collections import defaultdict

nums = [1, 2, 1, 3, 2, 1]

conteo = defaultdict(int)       # le estamos diciendo que inicialice cada clave con un 0 (int)
                                # si le dijéramos (str), inicializaría con una cadena vacía ("")

for n in nums:
    conteo[n] = conteo[n] + 1   # se pone así porque, inicialmente, conteo[n] tiene valor 0

print(conteo)
# Out:
# defaultdict(<class 'int'>, {1: 3, 2: 2, 3: 1})

# %% [markdown]
# ---
# ## 5️⃣ Comparativa rápida
#
# | Tipo | Ordenado | Mutable | Duplicados | Sintaxis |
# |:----:|:----------:|:----------:|:-------------:|:----------:|
# | `list` | ✅ | ✅ | ✅ | `[ ]` |
# | `tuple` | ✅ | ❌ | ✅ | `( )` |
# | `dict` | ✅ (3.7+) | ✅ | ❌ claves únicas | `{ clave: valor }` |
# | `set` | ❌ | ✅ | ❌ | `{ }` |
#
# ---
# ## 6️⃣ Ejercicio práctico
#
# Dada la siguiente lista:
# ```python
# nombres = ['ana', 'luis', 'ana', 'pepe', 'luis', 'maria']
# ```
# Crea un programa que:
# 1. Muestre los nombres únicos.
# 2. Cree un diccionario con el número de repeticiones.
# 3. Lo ordene por frecuencia descendente.

# %%
# Sesión estudio:

nombres = ['ana', 'luis', 'ana', 'pepe', 'luis', 'maria']

# 1. Mostrar los nombres únicos:

nombres_unicos = set(nombres)
print(nombres_unicos)
# Out:
# {'ana', 'luis', 'maria', 'pepe'}

# %%
# 2. Crear un diccionario con el número de repeticiones (con defaultdict):

from collections import defaultdict

conteo = defaultdict(int)

for nombre in nombres:
    conteo[nombre] = conteo[nombre] + 1

print(conteo)
# Out:
# defaultdict(<class 'int'>, {'ana': 2, 'luis': 2, 'pepe': 1, 'maria': 1})

# %%
# 2. Crear un diccionario con el número de repeticiones (sin defaultdict):

conteo_2 = {}

for nombre in nombres:
    if nombre not in conteo_2:
        conteo_2[nombre] = 1
    else:
        conteo_2[nombre] += 1

print(conteo_2)
# Out:
# {'ana': 2, 'luis': 2, 'pepe': 1, 'maria': 1}

# %%
# 3. Ordenar la lista por frecuencia descendente:

conteo.items()
# Out:
# dict_items([('ana', 2), ('luis', 2), ('pepe', 1), ('maria', 1)])

# %%
nombres = ['ana', 'luis', 'ana', 'pepe', 'luis', 'maria']
unicos = set(nombres)
conteo = {n: nombres.count(n) for n in unicos}
ordenado = dict(sorted(conteo.items(), key=lambda x: x[1], reverse=True))
print(ordenado)
# Out:
# {'ana': 2, 'luis': 2, 'maria': 1, 'pepe': 1}

# %% [markdown]
# ---
# ## 🧠 Resumen del notebook
#
# - `list`: estructura flexible y mutable.
# - `tuple`: versión inmutable para datos fijos.
# - `dict`: clave–valor, ideal para estructuras complejas.
# - `set`: conjunto sin duplicados, útil para operaciones matemáticas.
#
# 💡 Dominar estas colecciones es esencial para todo el trabajo con datos en Python.
