# %% [markdown]
# # 🧩 1.6 – Reemplazos y limpieza de texto con Expresiones Regulares
#
# En este notebook aprenderás a **modificar texto** mediante expresiones regulares:
# - Sustituciones simples (`re.sub`)
# - Sustituciones con **grupos** y **funciones personalizadas**
# - Normalización de datos reales (espacios, emails, logs)
#
# ---
# ## �� Objetivos
# - Comprender el uso de `re.sub()` y `re.subn()`.
# - Usar grupos capturados en reemplazos.
# - Limpiar y normalizar datos de texto comunes.

# %%
import re
print('✅ Módulo re cargado correctamente.')
# Out:
# ✅ Módulo re cargado correctamente.

# %% [markdown]
# ---
# ## 1️⃣ `re.sub()` – reemplazos directos
#
# `re.sub(patrón, reemplazo, texto)` devuelve una **nueva cadena** donde todas las coincidencias del patrón se reemplazan.
#
# Ejemplo: eliminar espacios múltiples o símbolos repetidos.

# %%
texto = 'Hola     mundo!!!   Python    es  genial!!!'

# Reemplazar varios espacios por uno solo
texto = re.sub(r'\s+', ' ', texto) # sustituye una o más repeticiones de espacio en blanco por un solo espacio
# Reemplazar múltiples ! por solo uno
texto = re.sub(r'!+', '!', texto)
print(texto)
# Out:
# Hola mundo! Python es genial!

# %% [markdown]
# ✅ `\s+` → uno o más espacios en blanco.
#
# ✅ `!+` → una o más exclamaciones repetidas.

# %% [markdown]
# ---
# ## 2️⃣ `re.subn()` – reemplazo con contador
#
# `re.subn()` funciona igual que `re.sub()`, pero devuelve **una tupla** con el texto resultante y el número de reemplazos realizados.

# %%
texto = 'Error Error Error'
nuevo, num = re.subn(r'Error', 'OK', texto)
print(nuevo)
print(f'Reemplazos: {num}')
# Out:
# OK OK OK
# Reemplazos: 3

# %%
texto = 'Error Error Error'
nuevo = re.subn(r'Error', 'OK', texto)
print("Nuevo texto:", nuevo[0])
print("Número de sustituciones:", nuevo[1])
# Out:
# Nuevo texto: OK OK OK
# Número de sustituciones: 3

# %% [markdown]
# ---
# ## 3️⃣ Reemplazo usando grupos capturados
#
# Puedes **reorganizar partes del texto** usando grupos `()` en el patrón y referencias `\1`, `\2`, etc. en el reemplazo.

# %%
texto = 'Apellido: García, Nombre: Ana'

# Intercambiamos el orden usando grupos
resultado = re.sub(r'Apellido: (\w+), Nombre: (\w+)', r'\2 \1', texto) # busca apellido y nombre y lo da la vuelta
print(resultado)
# Out:
# Ana García

# %% [markdown]
# ✅ `\1` y `\2` hacen referencia al **primer y segundo grupo** capturado respectivamente.

# %% [markdown]
# ---
# ## 4️⃣ Reemplazo dinámico con función
#
# `re.sub()` acepta una **función** como segundo argumento.
# La función recibe el objeto `Match` y debe devolver el texto reemplazado.
#
# Ejemplo: transformar todos los números del texto a su doble.

# %%
def duplicar(match):
    num = int(match.group())
    return str(num * 2)

texto = 'Hay 3 gatos, 5 perros y 1 tortuga.'
resultado = re.sub(r'\d+', duplicar, texto)
print(resultado)
# Out:
# Hay 6 gatos, 10 perros y 2 tortuga.

# %% [markdown]
# ✅ Cada número encontrado se pasa a la función `duplicar`, que devuelve el doble.
#
# Esto permite crear reemplazos **inteligentes y personalizados**.

# %% [markdown]
# ---
# ## 5️⃣ Limpieza de emails o URLs
#
# Ejemplo de anonimización de datos personales.

# %%
texto = 'Usuarios: ana@gmail.com, pedro@hotmail.com'

# Reemplazar emails por [EMAIL]
resultado = re.sub(r'[\w\.-]+@[\w\.-]+', '[EMAIL]', texto)
print(resultado)
# Out:
# Usuarios: [EMAIL], [EMAIL]

# %% [markdown]
# ✅ Patrón `[\w\.-]+@[\w\.-]+` captura direcciones de correo de forma genérica.

# %% [markdown]
# ---
# ## 6️⃣ Normalización de texto (pipeline)
#
# Ejemplo completo de **limpieza secuencial** con varios pasos:
# 1. Quitar etiquetas HTML.
# 2. Eliminar espacios y signos extra.
# 3. Pasar todo a minúsculas.
# 4. Sustituir números por `#`.

# %%
texto = '<b>¡Hola   Mundo!</b>   En 2025 tendremos  3 lanzamientos!!!'

def limpiar_texto(t):
    t = re.sub(r'<[^>]+>', '', t)           # quitar etiquetas HTML
    t = re.sub(r'!+', '!', t)              # colapsar signos
    t = re.sub(r'\s+', ' ', t)            # espacios extra
    t = re.sub(r'\d+', '#', t)            # sustituir números
    return t.strip().lower()              # .strip() elimina los espacios en blanco del principio y del final

print(limpiar_texto(texto))
# Out:
# ¡hola mundo! en # tendremos # lanzamientos!

# %% [markdown]
# ---
# ## 7️⃣ Ejercicio práctico – Limpieza de logs
#
# Dado el texto siguiente:
# ```
# [2025-10-31 10:00] INFO user=ana IP=10.0.0.1
# [2025-10-31 10:02] ERROR user=luis IP=192.168.1.5
# ```
# Queremos:
# - Reemplazar las IP por `[ANON]`
# - Convertir todo a minúsculas
# - Eliminar etiquetas `[INFO]` o `[ERROR]`
#
# 💡 *Pista:* encadena varios `re.sub()`.

# %%
texto = '[2025-10-31 10:00] INFO user=ana IP=10.0.0.1,[2025-10-31 10:02] ERROR user=luis IP=192.168.1.5'

def limpieza_logs(t):
    t = re.sub(r'IP=[\d\.]+', 'IP=[ANON]', t)
    t = re.sub(r'\[INFO\]|\[ERROR]', '', t)
    t = texto.strip().lower()
    return t

limpieza_logs(texto)
# Out:
# '[2025-10-31 10:00] info user=ana ip=10.0.0.1,[2025-10-31 10:02] error user=luis ip=192.168.1.5'

# %%
logs = '''[2025-10-31 10:00] INFO user=ana IP=10.0.0.1\n
[2025-10-31 10:02] ERROR user=luis IP=192.168.1.5'''

limpio = re.sub(r'\d+\.\d+\.\d+\.\d+', '[ANON]', logs)
limpio = re.sub(r'\[(INFO|ERROR)\]\s*', '', limpio)
print(limpio.lower())
# Out:
# [2025-10-31 10:00] info user=ana ip=[anon]
#
# [2025-10-31 10:02] error user=luis ip=[anon]

# %% [markdown]
# ---
# ## 8️⃣ Resumen del notebook
#
# - `re.sub()` permite reemplazos estáticos o dinámicos.
# - Los grupos `()` y funciones personalizadas amplían su poder.
# - Se usa frecuentemente en limpieza de texto, ETL y anonimización.
#
# ---
# **Fin del notebook 1.6 – Reemplazos y limpieza de texto.**
